# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import warnings
import os
import shutil
warnings.filterwarnings(action="ignore")

# %%
zip_files = list(filter(lambda x: '.zip' in x, os.listdir('../input/')))
zip_files
# Out:
# ['test_metadata.zip',
#  'test_images.zip',
#  'train_images.zip',
#  'test.zip',
#  'test_sentiment.zip',
#  'train_sentiment.zip',
#  'train_metadata.zip',
#  'train.zip']

# %%
def unzip(file, destination=''):
    to_unzip = '../input/' + file
    destination = '../input/' + destination
    with zipfile.ZipFile(to_unzip, 'r') as zip_ref:
        zip_ref.extractall(destination)

unzip('train.zip')
unzip('test.zip')

unzip('train_sentiment.zip', 'train_sentiment')
unzip('test_sentiment.zip', 'test_sentiment')

unzip('train_metadata.zip', 'train_metadata')
unzip('test_metadata.zip', 'test_metadata')

# Danger: ~60,000 images!
unzip('train_images.zip', 'train_images')
unzip('test_images.zip', 'test_images')

# %%
# move zip files to a separate folder to de-clutter workspace
def move_zips(move_from, move_to):
    zip_files = list(filter(lambda x: '.zip' in x, os.listdir(move_from)))
    if not os.path.exists(move_to):
        os.makedirs(move_to)
    for file in zip_files:
        shutil.move(move_from + file, move_to + file)

move_zips('../input/', '../input/source_zips/')

# %%
train_df = pd.read_csv('../input/train.csv')
test_df = pd.read_csv('../input/train.csv')

# %%
train_df.describe()
# Out:
#                Type           Age        Breed1        Breed2        Gender  \
# count  14993.000000  14993.000000  14993.000000  14993.000000  14993.000000
# mean       1.457614     10.452078    265.272594     74.009738      1.776162
# std        0.498217     18.155790     60.056818    123.011575      0.681592
# min        1.000000      0.000000      0.000000      0.000000      1.000000
# 25%        1.000000      2.000000    265.000000      0.000000      1.000000
# 50%        1.000000      3.000000    266.000000      0.000000      2.000000
# 75%        2.000000     12.000000    307.000000    179.000000      2.000000
# max        2.000000    255.000000    307.000000    307.000000      3.000000
#
#              Color1        Color2        Color3  MaturitySize     FurLength  \
# count  14993.000000  14993.000000  14993.000000  14993.000000  14993.000000
# mean       2.234176      3.222837      1.882012      1.862002      1.467485
# ...

# %%
train_df.head()
# Out:
#    Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 0     2       Nibble    3     299       0       1       1       7       0
# 1     2  No Name Yet    1     265       0       1       1       2       0
# 2     1       Brisco    1     307       0       1       2       7       0
# 3     1         Miko    4     307       0       2       1       2       0
# 4     1       Hunter    1     307       0       1       1       0       0
#
#    MaturitySize      ...        Health  Quantity  Fee  State  \
# 0             1      ...             1         1  100  41326
# 1             2      ...             1         1    0  41401
# 2             2      ...             1         1    0  41326
# 3             2      ...             1         1  150  41401
# 4             2      ...             1         1    0  41326
#
#                           RescuerID  VideoAmt  \
# 0  8480853f516546f6cf33aa88cd76c379         0
# 1  3082c7125d8fb66f7dd4bff4192c8b14         0
# ...

# %%
plt.rcParams['figure.figsize']=(10,10)
sns.pairplot(train_df, hue='Type')

# %%
corr_mat = train_df[train_df['Type'] == 2].corr(method='spearman')
fig, axes = plt.subplots(figsize=(12, 9))
# sns.heatmap(corr_mat[(corr_mat >= abs(0.2))], vmax=1, vmin=-1, 
#             square=True, cmap=sns.cm.rocket_r)
sns.heatmap(corr_mat, vmax=1, vmin=-1, 
            square=True, cmap=sns.cm.rocket_r)

# %%
quant_vars = [f for f in train_df.columns if train_df.dtypes[f] != 'object']
y_vars = ['AdoptionSpeed']

sns.set()
x_vars = quant_vars[1:6]
sns.pairplot(train_df[train_df['Type'] == 1], size=2.5, x_vars=x_vars, y_vars=y_vars, hue='Gender')
plt.show()

# %%
sns.distplot(train_df['AdoptionSpeed'], kde=False)
